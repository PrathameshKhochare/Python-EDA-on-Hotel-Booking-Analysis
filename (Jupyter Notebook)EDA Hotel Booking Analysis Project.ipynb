# %% [markdown]
# # Project Name - Hotel Booking Analysis

# %% [markdown]
# ### Project Type - EDA
# ### Contribution - Individual
#
# ### Team Member - Prathamesh Prakash Khochare

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ## Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# ## Define Your Business Objective?
# To Improve Marketing and revenue management strategy amoung Hotel industries.

# %% [markdown]
# ## General Guidelines : -

# %% [markdown]
# 1. Well-structured, formatted, and commented code is required.
#
# 2. Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
# The additional credits will have advantages over other students during Star Student selection.
#
#     [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#               without a single error logged. ]
# 3. Each and every logic should have proper comments.
#
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#  #Chart visualization code
# * Why did you pick the specific chart?
# * What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?
#   justify with specific reason.
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis ]

# %% [markdown]
# # Let's Begin !

# %% [markdown]
# ## Importing Essential Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
from datetime import datetime

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 20
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=10
plt.rcParams['ytick.labelsize']=10
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15

# %% [markdown]
# ## Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\PRATHA~1\AppData\Local\Temp/ipykernel_23020/1408506528.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
file_path = r"C:\Users\Prathamesh\Downloads\Hotel Bookings (2).csv"

# %% [markdown]
# # Read from Local path

# %%
df = pd.read_csv(r"C:\Users\Prathamesh\Downloads\Hotel Bookings (2).csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ## Reading Data

# %%
df = pd.read_csv(file_path)

# %% [markdown]
# # Some basic operations on Data such as Shape ,columns ,top and bottom rows,checking NAN and mean,max,25%,50%,75% through describe(), checking Object type and non null values through info()

# %%
# rows and columns in datasheet
df.shape
# Out:
# (119390, 32)

# %%
# object type and non null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# basic functions on numeric data
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# list of column names
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# total number of columns
len(df.columns)
# Out:
# 32

# %%
# null value check
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# basic functions on all data to find min max ,aggr,count etc.
df.describe(include ='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
# 1st five rows
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# last five columns
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# checking columns in datasheet in form of list
print(list(df.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %% [markdown]
# We have perform some basic operations on our data to analyze and gain meaningful insights.

# %% [markdown]
# ## Data Cleaning

# %%
# first we can create copy of original dataframe and make changes in this copy
df1 = df.copy()

# %%
# we can find null valus from data 
df1.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# sorting null values in descending manner
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'column',0:'Null values'})
# Out:
#                column  Null values
# 0             company       112593
# 1               agent        16340
# 2             country          488
# 3            children            4
# 4  reserved_room_type            0
# 5  assigned_room_type            0

# %%
# from above operations it is found that column country,children,agent and company have null values
# As Dtype of children,company and agent is float, we can replace null values with 0. Also Dtype of country is object we can replace null values with 'other'
df1['company'].fillna(0,inplace=True)
df1['agent'].fillna(0,inplace=True)
df1['children'].fillna(0,inplace=True)
df1['country'].fillna('Other',inplace=True)

# %%
#null check
df1.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# Checking for duplicate rows
df1.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# above operation shows datasheet has 31994 duplicated rows, we can drop this from df1
df1 = df1.drop_duplicates()

# %%
# Duplicate check
print(df1.duplicated().value_counts())
#shape
df1.shape
# Out:
# False    87396
# dtype: int64
# (87396, 32)

# %% [markdown]
# ## Adding columns for better analysis

# %% [markdown]
#  We can merge Stay in week days and weekend as total Stay.
# also we can merge number of childern,adults and babies as total people.
#
#  We can add revenue column which is miltiplication of adr and total stay.

# %%
# total_stay = weekdays + weekends
df1['total_stay'] = df1['stays_in_week_nights'] + df1['stays_in_weekend_nights']
#total_people = adults + children + babies
df1['total_people'] = df1['children'] + df1['adults'] + df1['babies']
# Adding Revenue, Revenue = adr*total_stay
df1['revenue'] = df1['adr'] * df1['total_stay']

# %% [markdown]
# Adding new column which shows room type allocated is same as assigned or not

# %%
df1['is_reserved_room_assigned'] = df1.apply(lambda x: 'same room type assigned' if x['reserved_room_type'] == x['assigned_room_type'] 
                                  else 'different room type assigned' , axis =1)

# %%
# varification of updation
print(list(df1.columns))
df1.shape
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date', 'total_stay', 'total_people', 'revenue', 'is_reserved_room_assigned']
# (87396, 36)

# %% [markdown]
# There are some rows in total_people are zero. so we can drop this rows.

# %%
# rows of total people with value zero
df1[df1['total_people'] == 0].shape
# Out:
# (166, 36)

# %%
# so we can drop this 166 rows
df1.drop(df1[df1['total_people'] == 0].index,inplace=True)

# %%
# check of drop operation
df1[df1['total_people'] == 0].shape
# Out:
# (0, 36)

# %% [markdown]
# #Converting Datatypes for some columns approprietly

# %% [markdown]
# As columns 'children','agent','company' and 'total_people'and 'revenue' have datatype float instead of int we can convert float to int.
# Also column 'reservation_status_date' has datatype object, we can convert into date type

# %%
# float to int
df1[['agent','company','children','total_people','revenue','adr']] = df1[['agent','company','children','total_people','revenue','adr']].astype('int64')

#Object to Date type
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# As columns is_cancel and is_repeated_guests have boolean values, we can convert them to string values for better understanding

# %%
#boolen to string
df1['is_canceled'] = df1['is_canceled'].replace([0,1],['not canceled','cancled'])
df1['is_repeated_guest'] = df1['is_repeated_guest'].replace([0,1],['not repeated guest','repeated guest'])

# %%
# verification
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87230 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87230 non-null  object
#  1   is_canceled                     87230 non-null  object
#  2   lead_time                       87230 non-null  int64
#  3   arrival_date_year               87230 non-null  int64
#  4   arrival_date_month              87230 non-null  object
#  5   arrival_date_week_number        87230 non-null  int64
#  6   arrival_date_day_of_month       87230 non-null  int64
#  7   stays_in_weekend_nights         87230 non-null  int64
#  8   stays_in_week_nights            87230 non-null  int64
#  9   adults                          87230 non-null  int64
#  10  children                        87230 non-null  int64
#  11  babies                          87230 non-null  int64
# ...

# %%
df1.shape
# Out:
# (87230, 36)

# %% [markdown]
# ### Till now we have cleaned out our Dataset. earlier we have 119390 row, after data cleaning we have 87230 rows left.

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# First we can find Correlation between some important numeric columns so that on the basis of correlation we can make some assumption and analyse further.

# %% [markdown]
# As we added columns total_stay and total_people we will not considering columns stays_in_weekend_nights,stays_in_week_nights,adults,children,babies etc

# %%
# new dataframe
imp_numeric_df1 = df1[['lead_time','total_people','is_repeated_guest','previous_cancellations','previous_bookings_not_canceled','booking_changes','agent','company',
                       'days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','revenue'
                       ]]

# %%
#plot size
plt.figure(figsize=(20,10))
# correlation Heatmap
sns.heatmap(imp_numeric_df1.corr(),annot=True)
plt.title('Co-rrelation of the imp. columns')
# Out:
# Text(0.5, 1.0, 'Co-rrelation of the imp. columns')

# %% [markdown]
# We can make assumptions as below from above correlation heatmap-:
# 1. total stay and lead time have slight positive correlation - we can assume that people generally plans little earlier and book hotels earlier before arival for long stay.
#
# 2. total people and adr have slight positive correlation - we can assume that Revenue of hotel bussiness propertional to the amount of guest.
#
# 3. revenue is positively correlated with toal stay,total people and adr ,that means revenue is dependent on bussiness of the hoteling model.

# %% [markdown]
# ## Hotel wise Analysis

# %% [markdown]
# #### Q1. Which type of hotels are more preffered by guests?

# %%
# finding total number of both hotels
most_preferable_hotel = df1.groupby('hotel')['hotel'].count()
most_preferable_hotel
# Out:
# hotel
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
# Visualization by the pie chart.
df1['hotel'].value_counts().plot.pie( explode =(0,0.05) ,autopct='%1.1f%%', figsize=(10,8),fontsize=20,colors = ['lightskyblue','yellow'])   
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %%
# bar plot
group_by_hotel = df1.groupby('hotel')
d1 = pd.DataFrame((group_by_hotel.size()/df1.shape[0])*100).reset_index().rename(columns = {0:'% Hotel count'})
plt.figure(figsize=(5,5))
sns.barplot(x= d1['hotel'], y= d1['% Hotel count'])
plt.show()

# %% [markdown]
# It is clear that around 60% bookings are for City Hotels whereas 40% are for Resort Hotels.

# %%
# Revenue wise hotel distribution
hotel_revenue = df1.groupby('hotel')['revenue'].sum()
hotel_revenue
# Out:
# hotel
# City Hotel      18752816
# Resort Hotel    15680529
# Name: revenue, dtype: int64

# %%
#Create the plot object
hotel_revenue.plot(kind='bar')

plt.title('Revenue of hotel type in Crore')
plt.ylabel('Revenue')
plt.xlabel('Hotel Type')
# Out:
# Text(0.5, 0, 'Hotel Type')

# %% [markdown]
# From above Pie chart/Bar plot it is clear that maximum hotel preffered by guests are City Hotels.
# The question ariese in mind as why City hotels are more prefferable?
# As the given data has no data related charges and facilities provided by both hotels, we are unable to compare both types based on hotel facilities and living rates.
# We simply make assumption as ,there is large amount of crowd in Cities on the other hand Resort hotels are mostly booked during long stay and fastive or vacation periods. may be this is one reason why City hoteles are more prefferable.
#
# Revenue wise, there is no huge difference in both types as City hotel generates 18 million revenue whereas Resort hotels generates 15 million.

# %% [markdown]
# We have seen from corrlation map that Revenue is depends on factors like Total stay,total people,adr etc.

# %% [markdown]
# We will try to find Prices of both hotel types as,
# total_Price = Avg. daily rate * total_people * total_stay

# %%
#set plot size
plt.figure(figsize=(10,8))

# Calculating total price
actual_guest = df1.loc[df1['is_canceled'] == "not canceled"]
actual_guest['price'] = actual_guest['adr'] * actual_guest['total_people'] * actual_guest['total_stay']
sns.lineplot(data = actual_guest, x = 'arrival_date_month', y = 'price', hue = 'hotel')
# Out:
# C:\Users\PRATHA~1\AppData\Local\Temp/ipykernel_10664/3866434432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actual_guest['price'] = actual_guest['adr'] * actual_guest['total_people'] * actual_guest['total_stay']
# <AxesSubplot:xlabel='arrival_date_month', ylabel='price'>

# %% [markdown]
# From above plot, It is evidence that City hotel Price ranges in specified limits.(Price not fluctuates too much)
# on the other hand, Resort hotel's price fluctuates too much.The reason  may be total people and total stay are 2 most deciding factors for Price calculation.
# Price is high in May to Sept. as this is peek duration of vacation.
#
# One reason of City hotels are more profitable than Resort is that From sept. to May i.e almost 8-9 months graph of resort lies below city hotel.

# %%
# Considering desiding factors towards revenue
avg_hotel_revenue_desiding_factors = df1.groupby('hotel')['total_stay','total_people','lead_time','revenue'].mean()
avg_hotel_revenue_desiding_factors
# Out:
# C:\Users\PRATHA~1\AppData\Local\Temp/ipykernel_10664/284011251.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_hotel_revenue_desiding_factors = df1.groupby('hotel')['total_stay','total_people','lead_time','revenue'].mean()
#               total_stay  total_people  lead_time     revenue
# hotel
# City Hotel      3.141945      2.021342  77.793257  352.006908
# Resort Hotel    4.391948      2.041289  83.387737  461.789640

# %% [markdown]
# ## Observation-
# From above Total Price Line plot and avg_hotel_revenue_desiding_factors datasheet , it is clear that out of 3 desiding factors,total people visiting both hotels are almost same but the reason of high revenue for Resort is total stay and lead time is higher than City hotels.
# But line plot shows almost 9 months city hotels are prefferable while Resort are till only 3-4 months.
# May be thats the reason of total revenue of Resort is slightly lesser than City hotels.

# %% [markdown]
# #### Q2. Which hotel has highest ADR ?

# %%
# ADR comparison
df1.groupby('hotel')['adr'].mean().reset_index()
# Out:
#           hotel         adr
# 0    City Hotel  111.017645
# 1  Resort Hotel   98.847067

# %%
#set plot size
plt.figure(figsize=(10,8))

# set labels
plt.title("Avg ADR of each Hotel type")
plt.ylabel('ADR')
plt.xlabel('Hotel type')


# bar plot
sns.barplot(y=df1['adr'],x=df1['hotel'])

# %% [markdown]
# City hotels has higher adr than Resort hotels.

# %% [markdown]
# ## Lets check for Which is dominent hotel type on yearly basis?

# %%
# Year wise bookings
columns_to_work = ['hotel','arrival_date_year','arrival_date_month','arrival_date_day_of_month']

arival_period = df1[columns_to_work]
sns.countplot(data = arival_period, x= 'arrival_date_year', hue = 'hotel')
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='count'>

# %% [markdown]
# #Observation-:
# City hotels had more bookings.
#
# Year 2016 had maximum booking and 2015 had very less bookings.
#
# Bookings rised almost doubled in 2016 as compared to 2015 , again rate of booking decreased in year 2017.

# %% [markdown]
# ## Cancellation Overview

# %% [markdown]
# #### What is total count of Cancelled bookings?
#
# #### Which Hotel has highest Cancellation rate?

# %%
#Cancellation_check 
sns.countplot(df1['is_canceled'])
# Out:
# C:\Users\Prathamesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='is_canceled', ylabel='count'>

# %% [markdown]
# Out of 87230, around 60000 bookings were not Cacelled.

# %% [markdown]
# Q Which hotel type has highest Cancellation rate?

# %%
plt.figure(figsize=(5,10))
clms_to_work = ['hotel','is_canceled']
hotel_wise_cancellation = df1[clms_to_work]
canceled_hotel = hotel_wise_cancellation[hotel_wise_cancellation['is_canceled'] == 'cancled'].groupby(['hotel']).size().reset_index(name = 'count')
canceled_hotel
sns.barplot(data = canceled_hotel, x = 'hotel', y = 'count').set_title('Graph showing cancellation rates in city and resort hotel')
# Out:
# Text(0.5, 1.0, 'Graph showing cancellation rates in city and resort hotel')

# %% [markdown]
# ## Observation -
# Cancellation rate is 2 times in City hotels as compared to Resort hotels.
# The reason is as City hotels have almost 60% of total bookings.

# %% [markdown]
# ## Which month had highest bookings?

# %%
# setting plot size
plt.figure(figsize=(20,5))
columns_to_work = ['hotel','arrival_date_year','arrival_date_month','arrival_date_day_of_month']

# mapping arrival with respective months
arival_period = df1[columns_to_work]
sns.countplot(data = arival_period, x = 'arrival_date_month', hue = 'hotel', order = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
          'August', 'September', 'October', 'November', 'December']).set_title('Graph showing number of arrival per month',fontsize=20)
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Both hotels types had highest bookings in August month and lowest in January.
# City hotels had average max. boookings in March to October.
# While Resort had average max. bookings in May to August.

# %% [markdown]
# Day wise booking -

# %%
# setting plot size
plt.figure(figsize=(20,5))

# mapping arrival with respective Days
arival_period = df1[columns_to_work]
sns.countplot(data = arival_period, x = 'arrival_date_day_of_month', hue = 'hotel').set_title('Graph showing number of arrival per month',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Graph showing number of arrival per month')

# %% [markdown]
# We do notice a roller coaster trend for the arrival day of month. Could the peaks belong to a weekend? (i.e Will people tend to book over the weekends?)

# %% [markdown]
# Lets check the bookings for Weekends and Weekdays.

# %%
# Plot of weekends booking
plt.figure(figsize=(20,5))
sns.countplot(data = df1 ,x= 'stays_in_weekend_nights').set_title('Graph showing number of arrivals on weekend nights',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Graph showing number of arrivals on weekend nights')

# %%
# Plot of weekdays booking
plt.figure(figsize=(20,5))
sns.countplot(data = df1 ,x= 'stays_in_week_nights').set_title('Graph showing number of arrivals on weekdays nights',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Graph showing number of arrivals on weekdays nights')

# %% [markdown]
# ### Observation -
# From weekend and weekdays count plot,it seems like booking is random over the days of month.

# %% [markdown]
# ## The Hotel Booking dataset has columns as meal, agent, country, is_repeated_guest, reserved_room_type, required_car_parking_spaces, booking_changes etc. we will generate some questions based on this columns

# %% [markdown]
# ### Which type of food is mostly preffered by guests?

# %%
df1.groupby('meal')['hotel'].count().reset_index().rename(columns = {'hotel':'count of meal type'})
# Out:
#         meal  count of meal type
# 0         BB               67907
# 1         FB                 360
# 2         HB                9080
# 3         SC                9391
# 4  Undefined                 492

# %%
# Pie plot representation
df1['meal'].value_counts().plot.pie(explode=[0.01, 0.01,0.01,0.01,0.01], autopct='%1.1f%%', shadow=False, figsize=(20,10),fontsize=10)
# Out:
# <AxesSubplot:ylabel='meal'>

# %% [markdown]
# Types of meal in hotels:
#
# BB - (Bed and Breakfast),
#
# HB- (Half Board),
#
# FB- (Full Board),
#
# SC- (Self Catering),

# %% [markdown]
# Observation - Almost 75-80 % guest prefer Bed and Breakfast
#               Full board is least prefferd type.
#
#  The reason may be as FB followed by HB are charging more amount than the Bed and Breakfast type and most are the guest are turist which prefer hotel only for night stay which include morning breakfast.

# %% [markdown]
# ###  Which agent made most booking?

# %%
# highest booking by agents
highest_booking = df1.groupby('agent')['agent'].agg({'count'}).reset_index().rename(columns = {'count':'Most booking'}).sort_values(by='Most booking',ascending= False)

# as agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_booking.drop(highest_booking[highest_booking['agent']==0].index,inplace=True) 

# Top 10 highest bookings
top_highest_booking = highest_booking.head(10)
top_highest_booking
# Out:
#      agent  Most booking
# 9        9         28721
# 174    240         13028
# 14      14          3342
# 7        7          3294
# 183    250          2779
# 175    241          1644
# 27      28          1493
# 8        8          1383
# 1        1          1228
# 6        6          1117

# %%
# Plotting Bar plot
plt.figure(figsize=(15,5))
sns.barplot(x= top_highest_booking['agent'], y = top_highest_booking['Most booking'], order= top_highest_booking['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ### Observation-
# Most number of booking made by agent 9 which is around 28000.

# %% [markdown]
# ### From Which Country, high number of guest are coming?

# %%
# Top 10 countries having maximum guests
guest_in_diff_countries = df1['country'].value_counts().reset_index().rename(columns= {'index' : 'Country Name', 'country' : 'Count of guests'})[:10]
guest_in_diff_countries
# Out:
#   Country Name  Count of guests
# 0          PRT            27355
# 1          GBR            10424
# 2          FRA             8823
# 3          ESP             7244
# 4          DEU             5385
# 5          ITA             3061
# 6          IRL             3015
# 7          BEL             2081
# 8          BRA             1993
# 9          NLD             1910

# %%
# Bar plot representation
plt.figure(figsize=(15,5))
sns.barplot(x= guest_in_diff_countries['Country Name'] , y= guest_in_diff_countries['Count of guests'], order= guest_in_diff_countries['Country Name'])
# Out:
# <AxesSubplot:xlabel='Country Name', ylabel='Count of guests'>

# %% [markdown]
# abbreevations for countries-
#
# PRT- Portugal
#
# GBR- United Kingdom
#
# FRA- France
#
# ESP- Spain
#
# DEU - Germany
#
# ITA -Itlay
#
# IRL - Ireland
#
# BEL -Belgium
#
# BRA -Brazil
#
# NLD-Netherlands

# %% [markdown]
# #### Observation -
# Most number of guest are coming from Portugal (above 25,000).
#
# More than 80% of guests coming from Portugal,UK,France,Spain and Germany.

# %% [markdown]
# ### What is the Percentage of Repeated Guests ?

# %%
# Pie chart representation
df1['is_repeated_guest'].value_counts().plot.pie(explode=(0.15,0.15),autopct='%1.1f%%',shadow=True,figsize=(10,8),fontsize=10)
# Out:
# <AxesSubplot:ylabel='is_repeated_guest'>

# %% [markdown]
# #### Observation -
# Only 4% of guests are revisiting the same hotel.
#
# In order to increse bussiness,hotel managememt should try to attract the guests by providing better deals.Discount,coupons are the one of the ways to attract the costomers.

# %% [markdown]
# ### Which is most preffered room type by the guests?

# %%
#set plotsize
plt.figure(figsize=(10,8))

#plotting 
sns.countplot(x=df1['reserved_room_type'],order=df1['reserved_room_type'].value_counts().index)
#  set xlabel for the plot
plt.xlabel('Room Type')
# set y label for the plot
plt.ylabel('Count of Room Type')
#set title for the plot
plt.title("Most prefferred Room type")
# Out:
# Text(0.5, 1.0, 'Most prefferred Room type')

# %% [markdown]
# #### Observation -
# Room type 'A' is the most prefferable room type.

# %%
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_stay',
#        'total_people', 'revenue', 'is_reserved_room_assigned'],
#       dtype='object')

# %% [markdown]
# ### What percentage of Car parking space is required by customers?

# %%
#checking number of rows in 'required_car_parking_spaces'
df1['required_car_parking_spaces'].value_counts().index
# Out:
# Int64Index([0, 1, 2, 3, 8], dtype='int64')

# %%
# Pie chart representation
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=(0.15,0.15,0.15,0.15,0.15),autopct='%1.1f%%',shadow=True,figsize=(10,8),fontsize=10,labels=None)
labels = df1['required_car_parking_spaces'].value_counts().index
# for better representation
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# #### Observation-
# 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %% [markdown]
# ### What is percentage of booking changes of the guest?

# %%
booking_changes_df=df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})

plt.figure(figsize=(10,8))
sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['Counts']*100/df1.shape[0])
plt.title("% of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# ## Observation -
# Almost 80% guest not change their bookings.

# %% [markdown]
# ### Which room had higher adr ?

# %%
#set plotsize
plt.figure(figsize=(18,10))

#removing outlier in adr which lies above 5000
df1.drop(df1[df1['adr'] > 5000].index, inplace = True)

# Box plot representation
sns.boxplot(x= df1['assigned_room_type'], y= df1['adr'])
plt.show()

# %% [markdown]
# #### Observation -
# Room type G,F,H had higher adr value.
#
# Room type A is most preffered,its adr is not that much high. that means people can afford the rates of room type A.
#
# In order to increase Revenue,management should increse Room type G,H,F,A.

# %% [markdown]
# ## Distribution Channel wise Analysis

# %% [markdown]
# ### Which Distribution channel is widely used for hotel booking ?

# %%
#checking number of rows in 'distribution_channel'
df1['distribution_channel'].value_counts().index
# Out:
# Index(['TA/TO', 'Direct', 'Corporate', 'GDS', 'Undefined'], dtype='object')

# %%
# setting figure size
plt.figure(figsize=(10,10))

#pie chart representation
df1['distribution_channel'].value_counts().plot.pie(explode=(0.01,0.01,0.015,0.015,0.015),autopct='%1.1f%%',shadow=False,labels=None)
labels = df1['distribution_channel'].value_counts().index

# for better representation
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# #### Observation -
# Travel agencies are more dominent type of booking.
#
# The reason may be,nowdays Travel agencies are providing all facilities like Travelling,stay,recommend placesto visits etc.
# various plans are attract people based on various budget range.
#
# Few people preffers Direct booking. Hotels are creating their webpages and provides all the information of facilities provided,previous ratings,images of hotels etc. so that people preffers direct bookings too.

# %% [markdown]
# ###  Which distribution channel brings better revenue generating deals for hotels?

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# grouping hotel type and Distibution channels
group_by_hotel_distribution = df1.groupby(['distribution_channel','hotel'])

# creating new dataframe
new_dataframe1 = pd.DataFrame(round((group_by_hotel_distribution['adr']).agg(np.mean),2)).reset_index().rename(columns={'adr': 'avg adr'})
new_dataframe2 = pd.DataFrame(round((group_by_hotel_distribution['revenue']).agg(np.mean),2)).reset_index().rename(columns={'revenue': 'avg revenue'})

# Bar plot representation
sns.barplot(ax = axes[0],x = new_dataframe1['distribution_channel'], y = new_dataframe1['avg adr'], hue = new_dataframe1['hotel'])
sns.barplot(ax = axes[1],x = new_dataframe2['distribution_channel'], y = new_dataframe2['avg revenue'], hue = new_dataframe2['hotel'])
plt.show()

# %% [markdown]
# #### Observation -
# #### 1st plot -
# 1st plot shows Global Distribution system generated highest revenue on the basis of ADR.
# City Hotel can work to increase outreach on GDS channels to get more higher revenue generating deals.
#
# #### 2nd plot -
# 2nd plot is on the basis of revenue which is calculated by considering total stay and total people.
# Hence Resort hotel's plot showing higher revenue for Travel agencies as TA/TA had higher i.e almost 80% of total bookings.

# %% [markdown]
# ### Which type of Deposit is most preffered ?

# %%
# how many types of deposite are provided?
df1['deposit_type'].value_counts().index
# Out:
# Index(['No Deposit', 'Non Refund', 'Refundable'], dtype='object')

# %%
# Pie chart representation
df1['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=False,figsize=(14,8),fontsize=20,labels=None)
plt.title("% Distribution of deposit type")
labels=df1['deposit_type'].value_counts().index

# for better representation
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# #### Observation -
# Almost all i.e. 98.7% guests preffers No Deposit for booking the hotel.

# %% [markdown]
# ### What is optimum days of stay preffered ?

# %%
# gruping based on total stay and hotel
group_by_stay = df1.groupby(['total_stay','hotel'])['is_canceled'].agg('count').reset_index().rename(columns= {'is_canceled':'total number of stays'})
group_by_stay
# Out:
#     total_stay         hotel  total number of stays
# 0            0    City Hotel                    231
# 1            0  Resort Hotel                    360
# 2            1    City Hotel                  10270
# 3            1  Resort Hotel                   6899
# 4            2    City Hotel                  10813
# ..         ...           ...                    ...
# 68          46  Resort Hotel                      1
# 69          48    City Hotel                      1
# 70          56  Resort Hotel                      2
# 71          60  Resort Hotel                      1
# 72          69  Resort Hotel                      1
#
# [73 rows x 3 columns]

# %%
# plot size
plt.figure(figsize=(15,10))

# Bar plot representation
sns.barplot(data= group_by_stay, x = 'total_stay', y= 'total number of stays' , hue= 'hotel').set_title('Day wise bookings')
# Out:
# Text(0.5, 1.0, 'Day wise bookings')

# %% [markdown]
# #### Observation -
# people mostly preffers within 7 days of stays.
#
# Also we can see as number of days are grater than 6 ,resort hotels graph is larger than City hotel, means we can say people having longer stay more than week preffers to Resort hotels.

# %% [markdown]
# ## Cancellation Analysis

# %% [markdown]
# ###  Which Market Segment has the higest cancellation rate?

# %% [markdown]
# First we will plot types of market segments

# %%
#check for number of market segment type
df1['market_segment'].value_counts().index
# Out:
# Index(['Online TA', 'Offline TA/TO', 'Direct', 'Groups', 'Corporate',
#        'Complementary', 'Aviation', 'Undefined'],
#       dtype='object')

# %%
#set plotsize
plt.figure(figsize=(10,5))
# Bar plot representation
sns.countplot(x= df1['market_segment']).set_title('Types of Market segments')
# Out:
# Text(0.5, 1.0, 'Types of Market segments')

# %% [markdown]
# Now we will check for Cancellation rate amoung all segments

# %%
#gruping counts of hotels based on market segments
market_segment_df = df1[df1['is_canceled'] == 'cancled']
market_segment_df = market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns = {0 : 'total counts'})
market_segment_df
# Out:
#    market_segment         hotel  total counts
# 0        Aviation    City Hotel            45
# 1   Complementary    City Hotel            54
# 2   Complementary  Resort Hotel            31
# 3       Corporate    City Hotel           263
# 4       Corporate  Resort Hotel           246
# 5          Direct    City Hotel           912
# 6          Direct  Resort Hotel           825
# 7          Groups    City Hotel           887
# 8          Groups  Resort Hotel           445
# 9   Offline TA/TO    City Hotel          1256
# 10  Offline TA/TO  Resort Hotel           800
# 11      Online TA    City Hotel         12615
# 12      Online TA  Resort Hotel          5627
# 13      Undefined    City Hotel             2

# %%
# plot size
plt.figure(figsize=(15,10))

# Bar plot representation
sns.barplot(data = market_segment_df, x= 'market_segment',y = 'total counts' ,hue = 'hotel').set_title('Cancellation rate for different Market Segments')
# Out:
# Text(0.5, 1.0, 'Cancellation rate for different Market Segments')

# %% [markdown]
# #### Observation -
# Online TA type has highest bookings also highest Cancellation ratio.
# As City hotels had more booking, it had more cancellation too.
#
# Hotel Management should work on this by providing refundable/no refundable deposit policies ,extra Coupon discounts for confirm guests etc.

# %% [markdown]
# ### Not getting same alloted room is reason for Cancellation of bookings?

# %%
df1['Same_room_alloted_or_not'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Same_room_alloted_or_not, dtype: int64

# %%
(grp_by_canceled_df).size()
# Out:
# is_canceled
# cancled         24008
# not canceled    63221
# dtype: int64

# %%
# Define a function for the reserved room type is same  or not as  assigned room type
def same_room_allotment(x):
  '''function to check whether the reserved room 
  type is same  or not as  assigned room type'''

  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
# create new column to df1
df1['Same_room_alloted_or_not']=df1.apply(lambda x: same_room_allotment(x),axis=1)

#groupby is canceled
grp_by_canceled_df=df1.groupby('is_canceled')

# create DF and calculate  percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:'percentage'})
DF

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x=DF.index,y=DF['percentage'])

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
# Out:
# Text(0, 0.5, '% of not getting same room as per reservation')

# %% [markdown]
# #### Observation -
# not geting same reseved room is not the reason for cancellation of bookings.

# %% [markdown]
# ### arriaval number of different age group and number of people

# %%
# non canceled typed bookings
not_canceled = df1[df1['is_canceled'] == 'not canceled']

# %%
## Select single, couple, multiple adults and family
single   = not_canceled[(not_canceled['adults']==1) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
couple   = not_canceled[(not_canceled['adults']==2) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
family   = not_canceled[not_canceled['adults'] + not_canceled['children'] + not_canceled['babies'] > 2]

reindex = ['January', 'February','March','April','May','June','July','August','September','October','November','December']

fig, ax = plt.subplots(figsize=(12, 8))

for type in ['single', 'couple', 'family']:
  d1 = eval(type).groupby(['arrival_date_month']).size().reset_index().rename(columns = {0:'arrival_num'})
  d1['arrival_date_month'] = pd.Categorical(d1['arrival_date_month'],categories=reindex,ordered=True)
  sns.lineplot(data=d1, x= 'arrival_date_month', y='arrival_num', label=type, ax=ax)
  
plt.grid()
plt.show()

# %% [markdown]
# #### Observations -
# Moslty bookings are done by couples(although we are not sure that they are couple as data doesn't tell about that)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# 1. City hotels are the most preferred hotel type by the guests.Around 60% bookings are for City Hotels whereas 40% are for Resort Hotels.Need to spend the most targeting fund on those hotel.
# 2. Revenue wise, there is no huge difference in both types as City hotel generates 18 million revenue whereas Resort hotels generates 15 million.
# 3. There is huge Price fluctuations in Resort hotels whereas City hotel price ranges in definite limits.The reason for this is as Resort hotel's bussiness model is seasonal based and City hotels have regular costomers.
# 4. City hotels had more bookings and more Cancellations. Year 2016 had maximum booking and 2015 had very less bookings.
# 5. Hotel industry should target months between April to Aug. Those are peak months specially for Resort hotels.
# 6. Almost 75-80 % guest prefer Bed and Breakfast Meal type.Full board is least prefferd Meal type.
# 7. Most number of booking made by agent 9 which is around 28000. and Room type A is most prefferable room type.
# 8. Most number of guests are coming from portugal.
# 9. Only 4% of guests are revisiting the same hotel.In order to increse bussiness,hotel managememt should try to attract the guests by providing better deals.Discount,coupons are the one of the ways to attract the costomers.
# 10. Most of the customers (91.6%) do not require car parking spaces.
# 11. Almost 80% guest not changed their bookings.
# 12. Room type G,F,H had higher adr value.Room type A is most preffered,its adr is not that much high. that means people can afford the rates of room type A.In order to increase Revenue,management should increse Room type G,H,F,A.
# 13. Almost 80% guests preffers Travel Agencies for thier bookings.
# 14. Global Distribution system generated highest revenue on the basis of ADR. City Hotel can work to increase outreach on GDS channels to get more higher revenue generating deals.
# 15. Optimal stay in both the type hotel is less than 7 days.
# 16. High rate of cancellations can be due high no deposit policies.
# 17. Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel.Only 2.5 % people cancelled the booking.
# 18. We can say,Moslty bookings are done by couples.
